# %% [markdown]
# <a href="https://colab.research.google.com/github/Samay-Kochhar/decision-analytics/blob/main/decisionanalytics_premiere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# --- 1.  paths to your two files ---------------------------------
csv_1 = "/content/Prem_2014-2019.csv"
csv_2 = "/content/Prem_2019-2024.csv"

# --- 2.  read them ------------------------------------------------
df1 = pd.read_csv(csv_1)
df2 = pd.read_csv(csv_2)

# --- 3.  parse Date → datetime, derive Season ---------------------
for df in (df1, df2):
    df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)
    df["Season"] = df["Date"].dt.year.where(df["Date"].dt.month >= 7,
                                            df["Date"].dt.year - 1)

# --- 4.  append / concatenate ------------------------------------
df = pd.concat([df1, df2], ignore_index=True)

# --- 5.  sort & give each row a unique MatchID -------------------
df = (df.sort_values(["Season", "Date", "HomeTeam", "AwayTeam"])
        .reset_index(drop=True))
df["MatchID"] = df.index + 1

print("Combined rows:", len(df))
print("Seasons:", sorted(df["Season"].unique()))
df
# Out:
# Combined rows: 3800
# Seasons: [np.int32(2014), np.int32(2015), np.int32(2016), np.int32(2017), np.int32(2018), np.int32(2019), np.int32(2020), np.int32(2021), np.int32(2022), np.int32(2023)]
# /tmp/ipython-input-5-1088642210.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst=True)
#      Div       Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0 2014-08-16           Arsenal  Crystal Palace     2     1   H     1
# 1     E0 2014-08-16         Leicester         Everton     2     2   D     1
# 2     E0 2014-08-16        Man United         Swansea     1     2   A     0
# 3     E0 2014-08-16               QPR            Hull     0     1   A     0
# 4     E0 2014-08-16             Stoke     Aston Villa     0     1   A     0
# ...   ..        ...               ...             ...   ...   ...  ..   ...
# 3795  E0 2024-05-19    Crystal Palace     Aston Villa     5     0   H     2
# 3796  E0 2024-05-19         Liverpool          Wolves     2     0   H     2
# 3797  E0 2024-05-19             Luton          Fulham     2     4   A     1
# 3798  E0 2024-05-19          Man City        West Ham     3     1   H     2
# 3799  E0 2024-05-19  Sheffield United       Tottenham     0     3   A     0
#
#       HTAG HTR  ...  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0        1   D  ...   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1        2   A  ...   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2        1   A  ...   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3        0   D  ...   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4        0   D  ...   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# ...    ...  ..  ...   ...       ...       ...    ...    ...      ...      ...
# 3795     0   H  ... -0.75      1.73      2.08   1.78   2.16     1.93     2.21
# 3796     0   H  ... -2.75      2.07      1.86   2.04   1.85     2.10     1.89
# 3797     2   A  ...  0.25      2.00      1.93   1.99   1.93     2.02     1.94
# 3798     1   H  ... -3.00      2.03      1.90   1.99   1.90     2.05     1.99
# 3799     1   A  ...  1.50      2.06      1.87   2.05   1.88     2.08     1.89
#
#       AvgCAHH  AvgCAHA  MatchID
# 0         NaN      NaN        1
# 1         NaN      NaN        2
# 2         NaN      NaN        3
# 3         NaN      NaN        4
# 4         NaN      NaN        5
# ...       ...      ...      ...
# 3795     1.81     2.05     3796
# 3796     2.04     1.82     3797
# 3797     1.96     1.91     3798
# 3798     1.96     1.91     3799
# 3799     2.01     1.86     3800
#
# [3800 rows x 132 columns]

# %%
#team names in each season

for yr in sorted(df["Season"].unique()):
    clubs = sorted(set(df.loc[df["Season"] == yr, "HomeTeam"]))
    print(f"\nSeason {yr}/{yr+1}:")
    print(", ".join(clubs))
# Out:
# Season 2014/2015:
# Arsenal, Aston Villa, Burnley, Chelsea, Crystal Palace, Everton, Hull, Leicester, Liverpool, Man City, Man United, Newcastle, QPR, Southampton, Stoke, Sunderland, Swansea, Tottenham, West Brom, West Ham
#
# Season 2015/2016:
# Arsenal, Aston Villa, Bournemouth, Chelsea, Crystal Palace, Everton, Leicester, Liverpool, Man City, Man United, Newcastle, Norwich, Southampton, Stoke, Sunderland, Swansea, Tottenham, Watford, West Brom, West Ham
#
# Season 2016/2017:
# Arsenal, Bournemouth, Burnley, Chelsea, Crystal Palace, Everton, Hull, Leicester, Liverpool, Man City, Man United, Middlesbrough, Southampton, Stoke, Sunderland, Swansea, Tottenham, Watford, West Brom, West Ham
#
# Season 2017/2018:
# Arsenal, Bournemouth, Brighton, Burnley, Chelsea, Crystal Palace, Everton, Huddersfield, Leicester, Liverpool, Man City, Man United, Newcastle, Southampton, Stoke, Swansea, Tottenham, Watford, West Brom, West Ham
#
# Season 2018/2019:
# Arsenal, Bournemouth, Brighton, Burnley, Cardiff, Chelsea, Crystal Palace, Everton, Fulham, Huddersfield, Leicester, Liverpool, Man City, Man United, Newcastle, Southampton, Tottenham, Watford, West Ham, Wolves
#
# Season 2019/2020:
# Arsenal, Aston Villa, Bournemouth, Brighton, Burnley, Chelsea, Crystal Palace, Everton, Leicester, Liverpool, Man City, Man United, Newcastle, Norwich, Sheffield United, Southampton, Tottenham, Watford, West Ham, Wolves
#
# Season 2020/2021:
# Arsenal, Aston Villa, Bournemouth, Brighton, Burnley, Chelsea, Crystal Palace, Everton, Fulham, Leeds, Leicester, Liverpool, Man City, Man United, Newcastle, Norwich, Sheffield United, Southampton, Tottenham, Watford, West Brom, West Ham, Wolves
#
# Season 2021/2022:
# Arsenal, Aston Villa, Brentford, Brighton, Burnley, Chelsea, Crystal Palace, Everton, Leeds, Leicester, Liverpool, Man City, Man United, Newcastle, Norwich, Southampton, Tottenham, Watford, West Ham, Wolves
#
# Season 2022/2023:
# Arsenal, Aston Villa, Bournemouth, Brentford, Brighton, Chelsea, Crystal Palace, Everton, Fulham, Leeds, Leicester, Liverpool, Man City, Man United, Newcastle, Nott'm Forest, Southampton, Tottenham, West Ham, Wolves
#
# Season 2023/2024:
# Arsenal, Aston Villa, Bournemouth, Brentford, Brighton, Burnley, Chelsea, Crystal Palace, Everton, Fulham, Liverpool, Luton, Man City, Man United, Newcastle, Nott'm Forest, Sheffield United, Tottenham, West Ham, Wolves

# %%
#also in this data there are 3 more teams in 2020/2021 season due to covid. Bournemouth, Norwich, watford
# three clubs you found that are NOT part of the 20-club primeiere league for 2020/21
extra_2020 = {"Bournemouth", "Norwich", "Watford"}

mask_keep = ~(
    (df["Season"] == 2020) &          # 2020 start-year ➜ 2020/21 season
    (df["HomeTeam"].isin(extra_2020) | df["AwayTeam"].isin(extra_2020))
)

df = df.loc[mask_keep].reset_index(drop=True)
print("Rows after dropping extras:", len(df))
# Out:
# Rows after dropping extras: 3781

# %%
# ------------------------------------------------------------------
# 1.  make sure club names are stripped of trailing spaces first
# ------------------------------------------------------------------
df["HomeTeam"] = df["HomeTeam"].str.strip()
df["AwayTeam"] = df["AwayTeam"].str.strip()

# ------------------------------------------------------------------
# 2.  build a dict: season  →  set( clubs )
# ------------------------------------------------------------------
clubs_by_season = (
    df.groupby("Season")
      .apply(lambda g: set(g["HomeTeam"]).union(g["AwayTeam"]))
)

# ------------------------------------------------------------------
# 3.  compute promoted clubs: new in season t vs t-1
# ------------------------------------------------------------------
promoted_by_season = {}
seasons_sorted = sorted(clubs_by_season.keys())

for i in range(1, len(seasons_sorted)):
    prev = clubs_by_season[seasons_sorted[i-1]]
    curr = clubs_by_season[seasons_sorted[i]]
    promoted_by_season[seasons_sorted[i]] = curr - prev    # newcomers

# ------------------------------------------------------------------
# 4.  inspect the result
# ------------------------------------------------------------------
for season, clubs in promoted_by_season.items():
    print(f"{season} → promoted:", ", ".join(sorted(clubs)))
# Out:
# 2015 → promoted: Bournemouth, Norwich, Watford
# 2016 → promoted: Burnley, Hull, Middlesbrough
# 2017 → promoted: Brighton, Huddersfield, Newcastle
# 2018 → promoted: Cardiff, Fulham, Wolves
# 2019 → promoted: Aston Villa, Norwich, Sheffield United
# 2020 → promoted: Fulham, Leeds, West Brom
# 2021 → promoted: Brentford, Norwich, Watford
# 2022 → promoted: Bournemouth, Fulham, Nott'm Forest
# 2023 → promoted: Burnley, Luton, Sheffield United
# /tmp/ipython-input-8-1721634851.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: set(g["HomeTeam"]).union(g["AwayTeam"]))

# %%
# 1)  remove duplicate league fixtures (same season-home-away)
dupe_mask = df.duplicated(["Season", "HomeTeam", "AwayTeam"], keep="first")
print("Duplicate rows removed by Home/Away pair:", dupe_mask.sum())

df = df.loc[~dupe_mask].reset_index(drop=True)

# 2)  verify 2020/21 now has exactly 380 rows
rows_2020 = len(df[df["Season"] == 2020])
print("Rows in 2020/21 after pair-dedup:", rows_2020)   # should print 380

# 3)  re-stamp the match-day column
def add_matchday(g):
    mpr = len(set(g["HomeTeam"]).union(g["AwayTeam"])) // 2   # 20→10
    g   = g.sort_values("Date").reset_index(drop=True)
    g["Matchday"] = g.index // mpr + 1
    return g

df = df.groupby("Season", group_keys=False).apply(add_matchday)

print(df.groupby("Season")["Matchday"].agg(["min","max"]).loc[2020])
# -> min 1 , max 38
# Out:
# Duplicate rows removed by Home/Away pair: 47
# Rows in 2020/21 after pair-dedup: 380
# min     1
# max    38
# Name: 2020, dtype: int64
# /tmp/ipython-input-9-1366337415.py:18: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Season", group_keys=False).apply(add_matchday)

# %%
# ─── Stamp the true Match-day BEFORE any rows are removed ─────────
def add_matchday(group):
    # Serie A has 20 clubs → 10 matches per round
    matches_per_round = 10
    # keep each season in chronological order
    group = group.sort_values("Date").reset_index(drop=True)
    # integer-divide the running row index by matches_per_round
    group["Matchday"] = group.index // matches_per_round + 1
    return group

# apply season-by-season
df = df.groupby("Season", group_keys=False).apply(add_matchday)
df
# Out:
# /tmp/ipython-input-10-2047477953.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Season", group_keys=False).apply(add_matchday)
#     Div       Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0 2014-08-16           Arsenal  Crystal Palace     2     1   H     1
# 1    E0 2014-08-16         Leicester         Everton     2     2   D     1
# 2    E0 2014-08-16        Man United         Swansea     1     2   A     0
# 3    E0 2014-08-16               QPR            Hull     0     1   A     0
# 4    E0 2014-08-16             Stoke     Aston Villa     0     1   A     0
# ..   ..        ...               ...             ...   ...   ...  ..   ...
# 375  E0 2024-05-19         Liverpool          Wolves     2     0   H     2
# 376  E0 2024-05-19             Luton          Fulham     2     4   A     1
# 377  E0 2024-05-19    Crystal Palace     Aston Villa     5     0   H     2
# 378  E0 2024-05-19           Chelsea     Bournemouth     2     1   H     1
# 379  E0 2024-05-19  Sheffield United       Tottenham     0     3   A     0
#
#      HTAG HTR  ... B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0       1   D  ...      NaN       NaN    NaN    NaN      NaN      NaN
# 1       2   A  ...      NaN       NaN    NaN    NaN      NaN      NaN
# 2       1   A  ...      NaN       NaN    NaN    NaN      NaN      NaN
# 3       0   D  ...      NaN       NaN    NaN    NaN      NaN      NaN
# 4       0   D  ...      NaN       NaN    NaN    NaN      NaN      NaN
# ..    ...  ..  ...      ...       ...    ...    ...      ...      ...
# 375     0   H  ...     2.07      1.86   2.04   1.85     2.10     1.89
# 376     2   A  ...     2.00      1.93   1.99   1.93     2.02     1.94
# 377     0   H  ...     1.73      2.08   1.78   2.16     1.93     2.21
# 378     0   H  ...     2.01      1.92   2.02   1.91     2.02     1.96
# 379     1   A  ...     2.06      1.87   2.05   1.88     2.08     1.89
#
#      AvgCAHH  AvgCAHA  MatchID  Matchday
# 0        NaN      NaN        1         1
# 1        NaN      NaN        2         1
# 2        NaN      NaN        3         1
# 3        NaN      NaN        4         1
# 4        NaN      NaN        5         1
# ..       ...      ...      ...       ...
# 375     2.04     1.82     3797        38
# 376     1.96     1.91     3798        38
# 377     1.81     2.05     3796        38
# 378     1.98     1.89     3795        38
# 379     2.01     1.86     3800        38
#
# [3734 rows x 133 columns]

# %%
#details of the matches played between the promoted teams, in next step these rows will be removed.
promoted_D1 = {
    2014: {"Burnley", "Leicester", "QPR"},          # 2014/15
    2015: {"Bournemouth", "Norwich", "Watford"},    # 2015/16
    2016: {"Burnley", "Hull", "Middlesbrough"},     # 2016/17
    2017: {"Brighton", "Huddersfield", "Newcastle"},# 2017/18
    2018: {"Cardiff", "Fulham", "Wolves"},          # 2018/19
    2019: {"Aston Villa", "Norwich", "Sheffield United"},   # 2019/20
    2020: {"Fulham", "Leeds", "West Brom"},         # 2020/21
    2021: {"Brentford", "Norwich", "Watford"},      # 2021/22
    2022: {"Bournemouth", "Fulham", "Nott'm Forest"},      # 2022/23
    2023: {"Burnley", "Luton", "Sheffield United"},         # 2023/24
}

# select and in next step delete the rows when mathc is between two promoted teams
mask_promoted_pair = df.apply(
    lambda r: r["Div"] == "E0"
           and r["HomeTeam"] in promoted_D1.get(r["Season"], set())
           and r["AwayTeam"] in promoted_D1.get(r["Season"], set()),
    axis=1
)

# to see which matches will be removed so to check basically
promoted_vs_promoted = df.loc[mask_promoted_pair,
                              ["Date", "Season", "HomeTeam", "AwayTeam"] \
                              + [col for col in df.columns if col not in
                                 {"Date","Season","HomeTeam","AwayTeam"}]]

print(f"{len(promoted_vs_promoted)} promoted-vs-promoted fixtures:")
print(promoted_vs_promoted.to_string(index=False))
# Out:
# 60 promoted-vs-promoted fixtures:
#       Date  Season         HomeTeam         AwayTeam Div  FTHG  FTAG FTR  HTHG  HTAG HTR      Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  BWD  BWA  IWH  IWD  IWA  LBH  LBD  LBA  PSH  PSD  PSA  WHH  WHD  WHA   SJH  SJD  SJA   VCH  VCD  VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA  Time  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA  IWCH  IWCD  IWCA  WHCH  WHCD  WHCA  VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  MatchID  Matchday
# 2014-10-04    2014        Leicester          Burnley  E0     2     2   D     2     1   H       P Dowd  15  10    6    4  16  12   9   3   2   2   0   0   1.80   3.75   5.00 1.80 3.40 4.50 1.75 3.50 4.50 1.80 3.60 5.00 1.79 3.72 5.16 1.80 3.25 5.00   NaN  NaN  NaN  1.80 3.70 5.00  44.00   1.82   1.78   3.75   3.57   5.19   4.80 44.00      2.13      2.01      1.85      1.78 24.00  -1.00     2.55     2.46     1.63     1.57  1.72  4.05  5.20   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN       63         7
# 2014-11-29    2014              QPR        Leicester  E0     3     2   H     2     1   H       R East  32  19    6    5   8  17  11   5   3   2   0   0   2.38   3.40   3.25 2.38 3.20 3.00 2.20 3.30 3.10 2.25 3.40 3.20 2.32 3.41 3.38 2.38 3.10 3.20   NaN  NaN  NaN  2.30 3.40 3.40  45.00   2.40   2.29   3.43   3.30   3.45   3.22 45.00      2.16      2.06      1.86      1.75 26.00  -0.25     2.01     1.97     1.95     1.91  2.53  3.34  3.08   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      124        13
# 2014-12-06    2014              QPR          Burnley  E0     2     0   H     0     0   D       J Moss  11  15    6    3  12  12   3  11   1   1   1   0   2.05   3.50   4.00 2.10 3.20 3.50 2.10 3.30 3.30 2.10 3.40 3.80 2.08 3.38 4.10 2.10 3.25 3.60   NaN  NaN  NaN  2.05 3.40 4.00  46.00   2.12   2.04   3.55   3.37   4.20   3.81 44.00      2.16      2.09      1.81      1.74 26.00  -0.50     2.08     2.02     1.90     1.86  2.00  3.50  4.22   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      145        15
# 2015-01-10    2014          Burnley              QPR  E0     2     1   H     2     1   H   A Marriner  18  17    7    7  14   9  10   6   2   2   0   0   2.20   3.40   3.60 2.20 3.25 3.25 2.20 3.20 3.20 2.20 3.30 3.40 2.16 3.47 3.70 2.20 3.30 3.30   NaN  NaN  NaN  2.20 3.40 3.60  46.00   2.25   2.14   3.50   3.36   3.77   3.48 44.00      2.14      2.03      1.87      1.78 26.00  -0.25     1.89     1.83     2.10     2.04  2.10  3.55  3.79   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      201        21
# 2015-04-25    2014          Burnley        Leicester  E0     0     1   A     0     0   D     A Taylor  12   8    4    4  16  16   6   4   3   0   0   0   2.63   3.30   2.90 2.55 3.30 2.80 2.50 3.30 2.65 2.45 3.30 3.00 2.50 3.34 3.10 2.62 2.88 3.00   NaN  NaN  NaN  2.55 3.40 3.00  48.00   2.63   2.49   3.48   3.27   3.10   2.93 47.00      2.09      2.00      1.88      1.80 30.00   0.00     1.84     1.78     2.19     2.10  2.78  3.36  2.76   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      328        33
# 2015-05-24    2014        Leicester              QPR  E0     5     1   H     2     0   H     M Oliver  22  18    7    2   7   6   5   6   0   0   0   0   1.60   4.33   6.00 1.60 3.80 5.50 1.60 3.90 5.00 1.62 4.00 5.50 1.57 4.57 6.02 1.62 3.80 5.50   NaN  NaN  NaN  1.57 4.50 6.00  43.00   1.65   1.56   4.57   4.21   6.20   5.71 34.00      1.59      1.55      2.65      2.41 28.00  -1.00     1.98     1.93     1.98     1.93  1.53  4.94  6.13   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      377        38
# 2015-09-12    2015          Norwich      Bournemouth  E0     3     1   H     1     0   H   M Atkinson  12   7    4    2  10  11   4   4   2   3   0   0   2.40   3.40   3.20 2.40 3.40 2.75 2.30 3.30 2.90 2.40 3.40 3.10 2.36 3.48 3.23 2.40 3.10 3.10  2.40 3.40 3.20 36.00 2.41 2.33   3.51   3.36   3.23   3.11  32.00   1.98   1.91  1.99      1.89     23.00     -0.25      2.04  1.99   1.91     1.87     2.42     3.48     3.13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      425         5
# 2015-10-03    2015      Bournemouth          Watford  E0     1     1   D     1     1   D     M Oliver  12  11    6    2   8  13   5   3   1   1   0   0   2.10   3.50   3.80 2.10 3.25 3.50 2.10 3.30 3.30 2.15 3.40 3.60 2.13 3.54 3.72 2.15 3.00 3.75  2.10 3.50 3.80 44.00 2.15 2.10   3.60   3.39   3.80   3.62  40.00   2.07   2.00  1.91      1.80     27.00     -0.50      2.13  2.08   1.85     1.79     2.21     3.34     3.72   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      452         8
# 2015-12-05    2015          Watford          Norwich  E0     2     0   H     1     0   H       M Dean  14   6    7    1  11  10   4   1   3   3   0   0   2.15   3.50   3.60 2.15 3.20 3.40 2.00 3.30 3.60 2.15 3.30 3.40 2.16 3.48 3.70 2.15 3.10 3.60  2.15 3.50 3.70 47.00 2.21 2.13   3.50   3.36   3.75   3.52  42.00   2.09   1.99  1.85      1.80     27.00     -0.25      1.88  1.84   2.08     2.02     2.35     3.43     3.30   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      527        15
# 2016-01-16    2015      Bournemouth          Norwich  E0     3     0   H     1     0   H     R Madley  15  10    8    3   8  13   5   3   1   1   0   0   1.91   3.60   4.50 1.90 3.50 4.25 1.90 3.45 3.80 1.85 3.50 4.33 1.89 3.68 4.54 1.95 3.10 4.33  1.87 3.60 4.75 44.00 1.95 1.88   3.68   3.49   4.75   4.35  42.00   2.12   2.07  1.83      1.75     27.00     -0.50      1.90  1.87   2.05     2.00     1.90     3.60     4.62   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      592        22
# 2016-02-27    2015          Watford      Bournemouth  E0     0     0   D     0     0   D     A Taylor  14  11    1    3  14  17   4   5   3   1   0   0   2.38   3.25   3.00 2.35 3.10 3.10 2.20 3.20 3.20 2.38 3.20 3.00 2.45 3.31 3.22 2.38 3.25 3.00  2.45 3.30 3.20 48.00 2.45 2.37   3.35   3.22   3.25   3.10  40.00   2.29   2.16  1.75      1.69     31.00     -0.25      2.09  2.03   1.88     1.83     2.64     3.36     2.91   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      644        27
# 2016-05-11    2015          Norwich          Watford  E0     4     2   H     3     1   H       R East  18  12    6    7   8  12   5   1   2   3   0   0   1.83   3.75   4.75 1.75 3.75 4.33 1.80 3.60 4.00 1.80 3.60 4.33 1.85 3.82 4.60 1.80 3.30 5.00  1.83 3.75 4.75 47.00 1.87 1.82   3.81   3.66   5.00   4.43  39.00   1.94   1.89  1.98      1.90     28.00     -0.75      2.13  2.07   1.83     1.79     1.88     3.98     4.19   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      749        37
# 2016-09-10    2016          Burnley             Hull  E0     1     1   D     0     0   D    P Tierney  13  11    2    3  13   3   5   9   2   0   0   0   2.45   3.10   3.40 2.40 3.10 3.20 2.50 3.20 2.75 2.40 3.20 3.25 2.44 3.21 3.36 2.30 3.10 3.30  2.40 3.20 3.40 56.00 2.50 2.41   3.21   3.14   3.44   3.22  40.00   2.60   2.41  1.60      1.55     32.00     -0.25      2.07  2.02   1.90     1.84     2.55     3.14     3.23   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      793         4
# 2016-12-05    2016    Middlesbrough             Hull  E0     1     0   H     0     0   D       M Dean  16   6    4    2   6  11  13   7   1   1   0   0   1.83   3.50   5.25 1.75 3.60 5.00 1.85 3.50 4.30 1.80 3.50 5.00 1.80 3.57 5.40 1.83 3.40 5.00  1.80 3.50 5.40 44.00 1.85 1.79   3.60   3.47   5.70   5.09  41.00   2.46   2.30  1.70      1.61     27.00     -1.00      2.62  2.47   1.60     1.56     1.92     3.38     4.93   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      900        14
# 2016-12-26    2016          Burnley    Middlesbrough  E0     1     0   H     0     0   D     C Pawson   6   8    4    2  17  18   7   3   6   5   0   0   2.90   3.10   2.60 2.85 3.10 2.55 2.75 3.20 2.65 2.90 3.00 2.50 3.06 3.18 2.64 3.00 3.10 2.62  3.00 3.10 2.70 51.00 3.10 2.97   3.20   3.10   2.72   2.61  46.00   2.59   2.48  1.58      1.53     28.00      0.00      2.12  2.05   1.88     1.81     2.97     3.18     2.71   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN      932        18
# 2017-02-25    2016             Hull          Burnley  E0     1     1   D     0     0   D   M Atkinson  15  10    1    3   8  13   6   3   1   1   0   1   2.15   3.30   3.90 2.15 3.25 3.60 2.20 3.35 3.30 2.15 3.10 3.75 2.20 3.22 3.91 2.20 3.10 3.80  2.15 3.30 3.90 48.00 2.25 2.16   3.35   3.22   3.92   3.74  45.00   2.40   2.30  1.68      1.62     25.00     -0.25      1.88  1.83   2.09     2.05     2.15     3.29     3.98   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1014        26
# 2017-04-05    2016             Hull    Middlesbrough  E0     4     2   H     3     2   H     M Oliver  17  12    5    4  13  12   8   4   2   1   0   0   2.05   3.30   4.20 2.00 3.30 4.00 2.20 3.35 3.30 2.00 3.10 4.00 2.08 3.32 4.20 2.05 3.20 4.20  2.10 3.30 4.10 45.00 2.20 2.05   3.50   3.27   4.30   4.04  43.00   2.48   2.36  1.65      1.59     24.00     -0.50      2.10  2.03   1.89     1.84     2.08     3.30     4.23   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1060        30
# 2017-04-08    2016    Middlesbrough          Burnley  E0     0     0   D     0     0   D   M Atkinson  12   7    5    2   9  12   4   3   0   3   0   0   2.45   3.10   3.40 2.40 3.10 3.20 2.50 3.30 2.85 2.38 3.00 3.25 2.42 3.15 3.45 2.40 3.00 3.20  2.45 3.13 3.40 46.00 2.50 2.42   3.30   3.12   3.45   3.24  40.00   2.53   2.42  1.61      1.55     24.00     -0.25      2.10  2.04   1.89     1.84     2.64     3.04     3.20   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1066        31
# 2017-08-20    2017     Huddersfield        Newcastle  E0     1     0   H     0     0   D     C Pawson   7  13    3    5  13  10   7   3   3   4   0   0   2.50   3.25   3.20 2.40 3.25 3.10 2.30 3.30 3.15 2.40 3.10 3.10 2.51 3.31 3.13 2.50 3.10 3.00  2.38 3.25 3.25 36.00 2.51 2.42   3.31   3.20   3.25   3.12  33.00   2.26   2.22  1.72      1.67     19.00     -0.25      2.14  2.08   1.85     1.81     2.83     3.21     2.81   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1158         2
# 2017-09-24    2017         Brighton        Newcastle  E0     1     0   H     0     0   D   A Marriner   7  17    3    5   6   8   2   8   2   1   0   0   2.80   3.10   2.90 2.70 3.10 2.80 2.65 3.30 2.65 2.65 3.00 2.80 2.78 3.10 2.96 2.70 3.10 2.70  2.75 3.13 2.90 40.00 2.85 2.70   3.30   3.10   2.96   2.83  36.00   2.55   2.40  1.62      1.57     18.00     -0.25      2.36  2.30   1.71     1.66     2.89     3.15     2.80   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1199         6
# 2017-12-09    2017     Huddersfield         Brighton  E0     2     0   H     2     0   H    S Attwell  19   7    6    2   6  10   8   1   0   0   0   0   2.70   3.10   3.00 2.55 3.00 3.10 2.60 3.20 2.80 2.55 2.90 3.00 2.69 3.02 3.15 2.62 2.90 3.00  2.70 3.00 3.13 38.00 2.73 2.63   3.20   2.97   3.20   3.04  34.00   3.01   2.78  1.47      1.43     23.00     -0.25      2.28  2.19   1.75     1.71     2.73     2.91     3.22   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1293        16
# 2017-12-30    2017        Newcastle         Brighton  E0     0     0   D     0     0   D     A Taylor  11  10    2    3  11  10   3   6   2   2   0   0   2.14   3.20   4.00 2.10 3.20 3.80 2.20 3.35 3.30 2.10 3.10 3.80 2.15 3.22 4.10 2.15 3.20 3.60  2.15 3.25 4.00 35.00 2.20 2.12   3.35   3.19   4.10   3.82  31.00   2.58   2.45  1.60      1.55     18.00     -0.25      1.84  1.80   2.13     2.08     2.16     3.22     4.05   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1346        21
# 2018-03-31    2017        Newcastle     Huddersfield  E0     1     0   H     0     0   D   M Atkinson  18   4    3    0   9  10   3   3   1   4   0   0   1.75   3.39   5.00 1.75 3.50 5.25 1.80 3.60 4.50 1.73 3.40 5.20 1.78 3.62 5.55 1.75 3.40 5.00  1.75 3.60 5.50 39.00 1.80 1.75   3.69   3.52   5.60   5.19  37.00   2.33   2.23  1.72      1.66     19.00     -0.75      2.03  1.98   1.93     1.88     1.78     3.63     5.45   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1449        31
# 2018-04-07    2017         Brighton     Huddersfield  E0     1     1   D     1     1   D     A Taylor  13  14    4    5  13   7   5   3   1   0   1   0   1.85   3.50   5.00 1.85 3.40 4.75 1.83 3.60 4.30 1.83 3.25 4.60 1.88 3.48 4.95 1.85 3.30 5.00  1.85 3.40 5.20 42.00 1.92 1.86   3.60   3.40   5.20   4.76  39.00   2.52   2.40  1.62      1.58     19.00     -0.50      1.89  1.85   2.07     2.02     1.76     3.70     5.46   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1456        32
# 2018-10-20    2018          Cardiff           Fulham  E0     4     2   H     2     2   D     K Friend  22   9    5    4  15  16   4   4   3   3   0   0   2.50   3.50   2.95 2.45 3.40 2.90 2.40 3.45 2.85 2.51 3.46 3.02 2.40 3.40 2.88 2.50 3.50 2.90 39.00 2.55 2.46  3.53 3.42 3.10   2.91  37.00   1.86   1.82   2.10   2.00  20.00 -0.25      2.19      2.12      1.81      1.77  2.62   3.45     2.88      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1602         9
# 2018-11-30    2018          Cardiff           Wolves  E0     2     1   H     0     1   A   A Marriner  17  15    3    4   3  12   7   6   1   2   0   0   3.80   3.25   2.20 3.50 3.20 2.20 3.30 3.30 2.25 3.76 3.32 2.22 3.75 3.25 2.20 3.80 3.20 2.25 38.00 3.80 3.64  3.32 3.20 2.31   2.21  35.00   2.49   2.38   1.63   1.59  20.00  0.25      2.06      2.00      1.91      1.87  3.63   3.28     2.28      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1651        14
# 2018-12-26    2018           Fulham           Wolves  E0     1     1   D     0     0   D   A Marriner  11  14    9    5   9   6   2   0   2   1   0   0   3.25   3.40   2.37 3.25 3.30 2.30 3.10 3.25 2.35 3.25 3.30 2.45 3.20 3.20 2.35 3.30 3.30 2.40 37.00 3.30 3.19  3.40 3.28 2.47   2.36  35.00   2.12   2.05   1.84   1.78  21.00  0.25      1.90      1.85      2.09      2.03  2.96   3.15     2.76      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1704        19
# 2019-03-02    2018           Wolves          Cardiff  E0     2     0   H     2     0   H   A Marriner  13  12    6    4  11   6   7   8   1   2   0   0   1.50   4.33   8.00 1.50 4.20 7.00 1.50 4.15 6.80 1.51 4.37 7.46 1.50 4.20 7.00 1.53 4.20 7.50 34.00 1.55 1.51  4.37 4.21 8.00   7.13  33.00   2.05   1.98   1.91   1.85  21.00 -1.00      1.91      1.86      2.05      2.00  1.78   3.55     5.59      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1806        29
# 2019-04-27    2018           Fulham          Cardiff  E0     1     0   H     0     0   D   C Kavanagh   8  13    2    8  10   8  10   3   0   0   0   0   2.40   3.60   3.00 2.35 3.50 2.95 2.35 3.50 2.90 2.40 3.71 2.95 2.30 3.60 3.00 2.40 3.60 3.10 35.00 2.45 2.37  3.71 3.56 3.10   2.93  34.00   1.80   1.73   2.20   2.11  17.00  0.00      1.80      1.74      2.23      2.15  2.21   3.69     3.35      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1874        36
# 2019-05-04    2018           Wolves           Fulham  E0     1     0   H     0     0   D       J Moss  19   6    6    2  10  15   7   1   1   3   0   0   1.53   4.20   7.50 1.55 4.10 6.25 1.55 4.15 6.30 1.56 4.16 6.69 1.53 4.00 7.00 1.57 4.10 7.00 34.00 1.57 1.55  4.35 4.12 7.50   6.52  32.00   1.85   1.80   2.10   2.03  21.00 -1.00      1.99      1.93      2.00      1.94  1.52   4.39     7.01      NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN   NaN      NaN      NaN   NaN   NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN        NaN        NaN     NaN     NaN       NaN       NaN       NaN       NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN      NaN      NaN     1886        37
# 2019-10-05    2019          Norwich      Aston Villa  E0     1     5   A     0     2   A     A Madley  21  22    5   12  14  17  10   6   1   3   0   0   2.37   3.60   2.80 2.30 3.60 2.95 2.35 3.65 2.80  NaN  NaN  NaN 2.46 3.61 2.91 2.40 3.60 2.80   NaN  NaN  NaN  2.40 3.70 2.80    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.46  3.62  2.90 15:00  2.50  3.75  2.95  2.41  3.60  2.85      1.57      2.37   1.61   2.48     1.63     2.52     1.57     2.43 -0.25     2.07     1.72  2.13  1.81    2.15    1.82    2.11    1.79    2.37    3.60    2.80  2.40  3.60  2.90  2.35  3.60  2.85  2.40  3.60  2.80  2.38  3.70  2.88   2.50   3.75   2.93   2.42   3.60   2.86       1.53       2.50    1.55    2.61      1.61      2.64      1.56      2.45 -0.25      2.13      1.81   2.14   1.80     2.16     1.84     2.11     1.80     1974         8
# 2019-12-08    2019          Norwich Sheffield United  E0     1     2   A     1     0   H     S Hooper  14   9    4    3   6  12   9   1   0   4   0   0   2.90   3.50   2.37 2.85 3.50 2.40 2.95 3.40 2.40  NaN  NaN  NaN 3.04 3.51 2.42 2.90 3.50 2.38   NaN  NaN  NaN  2.90 3.50 2.40    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  3.18  3.57  2.31 14:00  3.30  3.58  2.60  2.98  3.45  2.40      1.80      2.00   1.92   2.00     1.92     2.08     1.84     1.99  0.25     1.82     2.08  1.84  2.09    1.85    2.20    1.81    2.06    3.10    3.50    2.25  3.00  3.50  2.35  3.10  3.40  2.30  3.10  3.50  2.25  3.20  3.40  2.30   3.30   3.60   2.38   3.14   3.48   2.30       1.90       1.90    1.90    2.02      1.93      2.04      1.87      1.95  0.25      1.91      1.99   1.92   2.01     1.94     2.05     1.90     1.98     2059        16
# 2019-12-14    2019 Sheffield United      Aston Villa  E0     2     0   H     0     0   D     P Bankes   7   8    3    0  10   9   3   2   2   2   0   0   1.85   3.75   4.20 1.87 3.70 4.10 1.85 3.70 4.15  NaN  NaN  NaN 1.88 3.83 4.30 1.85 3.70 4.20   NaN  NaN  NaN  1.85 3.70 4.33    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.79  3.89  4.68 15:00  1.93  3.90  4.35  1.86  3.75  4.17      1.80      2.00   1.81   2.12     1.87     2.12     1.81     2.02 -0.50     1.86     2.04  1.88  2.05    1.93    2.08    1.85    2.01    1.75    3.90    4.40  1.83  3.75  4.33  1.85  3.60  4.30  1.78  3.75  4.50  1.75  3.90  4.60   1.90   4.00   5.00   1.78   3.88   4.51       1.72       2.10    1.71    2.26      1.75      2.28      1.70      2.17 -0.75      2.02      1.88   2.04   1.88     2.07     1.93     1.99     1.88     2065        17
# 2019-12-26    2019      Aston Villa          Norwich  E0     1     0   H     0     0   D   C Kavanagh  11  16    2    6  15  12   5   8   2   3   0   0   2.10   3.75   3.30 2.05 3.80 3.30 2.10 3.75 3.20  NaN  NaN  NaN 2.14 3.84 3.31 2.10 3.70 3.25   NaN  NaN  NaN  2.10 3.80 3.25    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.19  3.73  3.27 15:00  2.20  3.90  3.45  2.11  3.77  3.28      1.53      2.50   1.56   2.59     1.56     2.63     1.52     2.51 -0.25     1.86     2.04  1.88  2.05    1.88    2.07    1.85    2.02    2.20    3.75    3.00  2.25  3.50  3.10  2.20  3.75  3.05  2.15  3.70  3.20  2.20  3.80  3.10   2.30   3.85   3.27   2.20   3.72   3.14       1.53       2.50    1.55    2.62      1.56      2.63      1.52      2.51 -0.25      1.92      1.98   1.92   2.01     1.96     2.02     1.92     1.96     2080        18
# 2020-03-07    2019 Sheffield United          Norwich  E0     1     0   H     1     0   H     S Hooper  10  12    4    5  12   8  10   5   0   0   0   0   1.65   3.75   5.75 1.65 3.70 5.75 1.67 3.75 5.40  NaN  NaN  NaN 1.66 3.87 5.87 1.65 3.70 5.80   NaN  NaN  NaN  1.65 3.70 6.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.66  4.07  5.48 15:00  1.70  3.90  6.05  1.66  3.78  5.71      2.10      1.72   2.16   1.78     2.16     1.82     2.06     1.77 -0.75     1.87     2.03  1.87  2.06    1.91    2.06    1.86    2.01    1.66    3.75    5.25  1.70  3.80  5.25  1.67  3.75  5.30  1.65  3.90  5.25  1.70  3.75  5.50   1.73   4.15   5.70   1.68   3.88   5.37       2.00       1.80    2.13    1.80      2.24      1.84      2.06      1.77 -0.75      1.85      2.05   1.88   2.05     1.90     2.09     1.86     2.02     2183        28
# 2020-06-17    2019      Aston Villa Sheffield United  E0     0     0   D     0     0   D     M Oliver  14   5    6    1  11  14  12   4   1   1   0   0   3.20   3.40   2.25 3.20 3.40 2.20 3.25 3.30 2.25  NaN  NaN  NaN 3.48 3.37 2.28 3.30 3.30 2.25   NaN  NaN  NaN  3.30 3.30 2.25    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  3.33  3.38  2.35 18:00  3.48  3.45  2.39  3.30  3.33  2.27      2.10      1.72   2.17   1.78     2.19     1.84     2.08     1.76  0.25     1.93     1.97  1.97  1.95    1.97    2.01    1.92    1.94    3.30    3.25    2.30  3.25  3.25  2.30  3.25  3.25  2.30  3.25  3.30  2.30  3.40  3.25  2.30   3.50   3.44   2.43   3.28   3.29   2.32       2.20       1.66    2.26    1.71      2.30      1.82      2.17      1.71  0.25      1.94      1.99   1.92   2.01     1.96     2.02     1.90     1.98     2189        29
# 2020-09-19    2020            Leeds           Fulham  E0     4     3   H     2     1   H     A Taylor  10  14    7    6  13  18   5   3   1   2   0   0   1.61   3.90   5.75 1.62 4.00 5.50 1.65 3.70 5.50  NaN  NaN  NaN 1.65 4.05 5.61 1.63 3.90 5.50   NaN  NaN  NaN  1.62 3.90 6.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.75  3.91  5.12 15:00  1.70  4.15  6.00  1.64  3.97  5.50      1.97      1.93   1.96   1.96     1.99     2.00     1.93     1.91 -0.75     1.81     2.09  1.85  2.08    1.86    2.14    1.82    2.07    1.66    3.80    5.25  1.67  4.00  5.00  1.75  3.55  4.90  1.70  3.70  5.25  1.73  3.70  5.25   1.80   4.00   5.70   1.73   3.81   5.05       2.01       1.89    2.03    1.89      2.04      2.05      1.96      1.88 -0.75      1.97      1.93   1.99   1.94     2.01     2.03     1.95     1.93     2291         6
# 2020-11-02    2020           Fulham        West Brom  E0     2     0   H     2     0   H     S Hooper  13  10    6    1  13  11   5   2   3   2   0   0   2.40   3.30   3.00 2.40 3.30 3.00 2.45 3.10 3.00  NaN  NaN  NaN 2.47 3.40 3.13 2.40 3.30 3.00   NaN  NaN  NaN  2.45 3.25 3.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.48  3.32  3.19 17:30  2.56  3.50  3.17  2.44  3.32  3.01      2.00      1.80   2.13   1.80     2.14     1.85     2.06     1.78 -0.25     2.10     1.80  2.11  1.84    2.15    1.86    2.10    1.80    2.40    3.30    3.00  2.45  3.30  2.95  2.40  3.05  3.10  2.40  3.20  3.10  2.40  3.25  3.10   2.48   3.45   3.22   2.41   3.27   3.09       2.05       1.85    2.05    1.88      2.11      1.92      2.02      1.81 -0.25      2.06      1.84   2.11   1.84     2.12     1.87     2.08     1.82     2347        11
# 2020-12-29    2020        West Brom            Leeds  E0     0     5   A     0     4   A      L Mason   4  14    1    6   7  10   3  10   0   1   0   0   3.60   3.60   2.00 3.60 3.70 2.00 3.50 3.65 2.00  NaN  NaN  NaN 3.72 3.71 2.06 3.60 3.50 2.05   NaN  NaN  NaN  3.50 3.75 2.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  4.35  4.04  1.83 18:00  4.07  3.83  2.12  3.59  3.67  2.03      1.57      2.37   1.65   2.38     1.67     2.42     1.61     2.32  0.50     1.85     2.05  1.87  2.06    1.88    2.12    1.83    2.04    4.00    4.00    1.80  4.10  4.00  1.80  4.10  3.60  1.90  4.20  3.90  1.80  4.20  3.90  1.80   4.60   4.15   1.90   4.23   3.96   1.81       1.61       2.30    1.68    2.30      1.69      2.38      1.64      2.28  0.75      1.86      2.04   1.88   2.06     1.96     2.08     1.86     2.02     2434        19
# 2021-01-30    2020        West Brom           Fulham  E0     2     2   D     0     1   A     A Taylor   5  12    3    7   9  10   2   3   1   0   0   0   3.30   3.20   2.30 3.30 3.20 2.30 3.30 3.20 2.30  NaN  NaN  NaN 3.43 3.26 2.36 3.30 3.10 2.35   NaN  NaN  NaN  3.30 3.20 2.30    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  3.60  3.41  2.22 15:00  3.45  3.27  2.44  3.33  3.19  2.32      2.20      1.66   2.27   1.69     2.29     1.78     2.18     1.70  0.25     1.91     1.99  1.92  2.01    1.95    2.02    1.89    1.98    3.50    3.30    2.15  3.50  3.30  2.15  3.55  3.25  2.15  3.50  3.10  2.25  3.50  3.20  2.20   3.68   3.45   2.50   3.53   3.29   2.20       2.20       1.66    2.22    1.73      2.34      1.76      2.18      1.70  0.25      2.01      1.92   2.03   1.90     2.03     1.97     1.99     1.89     2481        23
# 2021-03-19    2020           Fulham            Leeds  E0     1     2   A     1     1   D      D Coote  13  13    6    4  13  12  13   7   2   2   0   0   2.37   3.40   3.00 2.40 3.40 2.95 2.45 3.25 3.00  NaN  NaN  NaN 2.48 3.42 3.07 2.40 3.30 3.00   NaN  NaN  NaN  2.40 3.30 3.10    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.56  3.45  2.94 20:00  2.50  3.52  3.10  2.43  3.35  3.00      2.00      1.80   2.09   1.82     2.14     1.87     2.05     1.79 -0.25     2.10     1.83  2.13  1.82    2.14    1.84    2.11    1.81    2.50    3.30    2.87  2.60  3.30  2.75  2.55  3.25  2.85  2.55  3.30  2.80  2.60  3.25  2.88   2.65   3.45   2.94   2.57   3.29   2.84       2.20       1.66    2.16    1.77      2.21      1.85      2.11      1.74  0.00      1.86      2.07   1.83   2.11     1.88     2.11     1.84     2.04     2567        30
# 2021-05-23    2020            Leeds        West Brom  E0     3     1   H     2     0   H      D Coote  17  14    9    5  12  12   8   3   2   1   0   0   1.40   5.25   6.50 1.45 5.00 6.25 1.45 5.25 6.25  NaN  NaN  NaN 1.45 5.24 6.54 1.42 5.00 7.00   NaN  NaN  NaN  1.40 5.00 7.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.54  4.81  5.69 16:00  1.49  5.50  7.00  1.44  5.18  6.51      1.40      3.00   1.53   2.61     1.44     3.12     1.41     2.91 -1.25     1.93     1.97  1.94  1.96    1.96    2.01    1.91    1.97    1.53    4.75    5.25  1.55  4.60  5.25  1.53  4.70  5.50  1.50  4.80  5.80  1.55  4.50  5.75   1.59   4.92   6.20   1.54   4.69   5.59       1.53       2.50    1.52    2.67      1.57      2.82      1.50      2.60 -1.00      1.88      2.02   1.90   2.01     1.94     2.14     1.87     2.00     2654        38
# 2021-09-18    2021          Norwich          Watford  E0     1     3   A     1     1   D      R Jones  12  12    5    8  10  14   4   8   1   1   0   0   2.15   3.30   3.50 2.15 3.40 3.40 2.15 3.35 3.45  NaN  NaN  NaN 2.21 3.48 3.53 2.15 3.30 3.50   NaN  NaN  NaN  2.15 3.20 3.40    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.41  3.29  3.31 15:00  2.28  3.52  3.60  2.18  3.39  3.47      2.10      1.72   2.13   1.79     2.25     1.81     2.11     1.76 -0.25     1.91     2.02  1.90  2.02    1.98    2.06    1.88    2.01    2.25    3.30    3.30  2.15  3.40  3.40  2.30  3.25  3.25  2.25  3.25  3.30  2.30  3.30  3.30   2.41   3.50   3.52   2.30   3.30   3.34       2.10       1.80    2.08    1.83      2.14      1.91      2.07      1.79 -0.25      2.04      1.89   2.05   1.88     2.05     1.99     1.98     1.90     2706         5
# 2021-11-06    2021        Brentford          Norwich  E0     1     2   A     0     2   A    J Gillett  19   9    7    5  12  13   6   2   2   3   0   0   1.60   4.00   5.75 1.63 3.80 5.25 1.63 3.90 5.75  NaN  NaN  NaN 1.63 4.05 6.06 1.61 3.70 5.80   NaN  NaN  NaN  1.60 3.70 5.75    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.68  4.07  5.46 15:00  1.68  4.05  6.06  1.63  3.92  5.80      2.00      1.80   2.06   1.85     2.12     1.87     2.03     1.82 -0.75     1.82     2.11  1.83  2.12    1.85    2.13    1.82    2.09    1.60    4.00    5.50  1.63  3.80  5.50  1.73  3.65  5.00  1.60  3.80  5.80  1.65  3.90  5.75   1.73   4.20   6.13   1.64   3.97   5.53       1.97       1.93    1.97    1.93      2.06      2.07      1.94      1.91 -0.75      1.88      2.05   1.88   2.05     1.90     2.24     1.84     2.06     2762        11
# 2021-12-10    2021        Brentford          Watford  E0     2     1   H     0     1   A     M Oliver  14   6    5    2  12  18   8   2   4   0   0   0   2.25   3.30   3.30 2.05 3.50 3.50 2.30 3.30 3.25  NaN  NaN  NaN 2.32 3.33 3.44 2.20 3.20 3.40   NaN  NaN  NaN  2.30 3.40 3.25    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.63  3.45  2.82 20:00  2.36  3.45  3.45  2.29  3.32  3.34      2.01      1.89   2.01   1.89     2.10     1.93     1.99     1.85 -0.25     1.97     1.93  1.98  1.94    2.01    1.96    1.95    1.93    2.45    3.30    2.87  2.05  3.50  3.50  2.50  3.30  2.90  2.45  3.40  2.80  2.50  3.40  2.90   2.63   3.65   3.21   2.52   3.32   2.94       1.97       1.93    1.93    1.96      2.04      2.05      1.96      1.87  0.00      1.83      2.07   1.88   2.03     1.88     2.25     1.82     2.07     2810        15
# 2022-01-21    2021          Watford          Norwich  E0     0     3   A     0     0   D       M Dean  15   7    4    2  16  11   5   1   0   1   1   0   2.00   3.50   3.75 2.05 3.60 3.50 2.10 3.45 3.55  NaN  NaN  NaN 2.09 3.53 3.66 2.05 3.40 3.60   NaN  NaN  NaN  2.05 3.50 3.75    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.07  3.54  3.88 20:00  2.12  3.62  3.78  2.07  3.52  3.63      1.94      1.96   1.93   1.94     1.95     1.99     1.90     1.93 -0.50     2.08     1.85  2.09  1.81    2.11    1.86    2.07    1.82    2.00    3.50    3.75  1.93  3.60  3.80  2.05  3.45  3.65  2.00  3.40  3.75  2.00  3.50  3.90   2.10   3.60   3.95   2.04   3.52   3.78       2.04       1.86    2.04    1.88      2.06      1.93      1.97      1.86 -0.50      2.07      1.86   2.07   1.86     2.09     1.88     2.04     1.84     2865        21
# 2022-03-05    2021          Norwich        Brentford  E0     1     3   A     0     1   A     A Taylor  15  10    7    6  13  18   5   5   2   5   0   0   2.90   3.10   2.50 2.90 3.10 2.55 2.90 3.10 2.60  NaN  NaN  NaN 3.04 3.19 2.64 2.88 3.10 2.55   NaN  NaN  NaN  2.88 3.00 2.55    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  3.22  3.25  2.48 15:00  3.04  3.34  2.68  2.95  3.15  2.60      2.30      1.61   2.34   1.66     2.38     1.70     2.28     1.64  0.00     2.05     1.85  2.11  1.83    2.11    1.89    2.05    1.83    3.10    3.10    2.40  3.00  3.10  2.45  3.05  3.15  2.45  3.10  3.00  2.45  3.13  3.20  2.45   3.43   3.26   2.55   3.12   3.18   2.47       2.20       1.66    2.19    1.75      2.33      1.77      2.19      1.69  0.25      1.81      2.09   1.83   2.11     1.95     2.15     1.81     2.09     2923        27
# 2022-04-16    2021          Watford        Brentford  E0     1     2   A     0     1   A     S Hooper  17  16    4    5  11   9   6   5   2   1   0   0   2.70   3.30   2.55 2.80 3.20 2.55 2.80 3.25 2.60  NaN  NaN  NaN 2.95 3.33 2.62 2.80 3.20 2.55   NaN  NaN  NaN  2.80 3.13 2.55    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.94  3.39  2.58 15:00  2.95  3.40  2.65  2.86  3.28  2.59      2.10      1.72   2.17   1.76     2.24     1.82     2.12     1.74  0.00     2.06     1.84  2.09  1.85    2.09    1.86    2.05    1.83    2.87    3.30    2.45  2.87  3.25  2.50  2.95  3.25  2.50  3.00  3.30  2.35  3.00  3.30  2.50   3.23   3.50   2.60   2.98   3.32   2.49       2.05       1.85    2.07    1.85      2.13      1.93      2.03      1.81  0.25      1.70      2.10   1.75   2.20     1.84     2.28     1.77     2.12     2973        32
# 2022-09-03    2022    Nott'm Forest      Bournemouth  E0     2     3   A     2     0   H     M Oliver  11   8    3    3  13  10   4   6   2   1   0   0   1.95   3.50   3.80 2.00 3.40 3.80 2.00 3.45 3.80  NaN  NaN  NaN 2.05 3.51 4.00 2.00 3.40 3.80   NaN  NaN  NaN  1.95 3.30 3.90    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.21  3.38  3.65 15:00  2.06  3.56  4.00  2.02  3.47  3.89      2.10      1.72   2.16   1.76     2.18     1.80     2.10     1.75 -0.50     2.02     1.88  2.05  1.88    2.05    1.91    2.02    1.86    2.15    3.30    3.50  2.20  3.25  3.40  2.20  3.30  3.45  2.15  3.30  3.40  2.20  3.30  3.60   2.30   3.50   3.76   2.20   3.35   3.53       2.10       1.72    2.21    1.74      2.35      1.79      2.14      1.73 -0.25      1.87      2.03   1.89   2.04     1.94     2.08     1.87     2.00     3096         6
# 2022-09-16    2022    Nott'm Forest           Fulham  E0     2     3   A     1     0   H    J Gillett  11  15    3    7  11  10   2  10   2   4   0   0   2.75   3.30   2.62 2.75 3.40 2.50 2.75 3.35 2.60  NaN  NaN  NaN 2.82 3.43 2.67 2.75 3.40 2.50   NaN  NaN  NaN  2.70 3.30 2.55    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.80  3.49  2.64 20:00  2.92  3.54  2.68  2.81  3.40  2.57      1.93      1.97   1.94   1.96     1.93     2.00     1.88     1.94  0.00     2.01     1.89  2.02  1.91    2.03    1.91    2.00    1.86    2.75    3.30    2.60  2.75  3.40  2.50  2.80  3.35  2.55  2.75  3.25  2.55  2.70  3.30  2.50   2.94   3.50   2.68   2.80   3.39   2.58       1.90       2.00    1.92    1.99      1.93      2.03      1.88      1.95  0.00      2.02      1.88   2.02   1.90     2.08     1.90     2.01     1.86     3102         7
# 2022-10-15    2022           Fulham      Bournemouth  E0     2     2   D     1     2   A      G Scott  19  10    4    6   9  11   5   6   2   0   0   0   1.85   3.75   4.00 1.87 3.70 4.00 1.90 3.65 4.00  NaN  NaN  NaN 1.92 3.77 4.23 1.88 3.60 4.00   NaN  NaN  NaN  1.83 3.50 4.20    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.98  3.69  4.03 15:00  1.96  3.90  4.30  1.89  3.72  4.13      1.96      1.94   1.99   1.92     1.99     2.02     1.90     1.92 -0.50     1.88     2.02  1.92  2.01    1.92    2.05    1.89    1.98    1.90    3.60    4.00  1.95  3.50  3.80  1.95  3.60  3.85  1.95  3.40  3.90  1.91  3.50  3.90   2.02   3.75   4.18   1.96   3.60   3.94       1.92       1.98    1.93    1.98      2.09      2.01      1.92      1.91 -0.50      1.97      1.93   1.98   1.94     2.02     1.96     1.96     1.91     3129         9
# 2023-01-21    2022      Bournemouth    Nott'm Forest  E0     1     1   D     1     0   H     A Madley  16  20    4    5  10   7   4   6   1   2   0   0   2.75   3.10   2.75 2.70 3.20 2.65 2.75 3.15 2.70  NaN  NaN  NaN 2.86 3.15 2.82 2.70 3.10 2.70   NaN  NaN  NaN  2.70 3.00 2.70    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.93  3.22  2.71 15:00  2.86  3.35  2.88  2.76  3.18  2.76      2.30      1.62   2.41   1.63     2.42     1.72     2.28     1.65  0.00     1.95     1.95  1.98  1.94    1.98    1.99    1.92    1.94    2.75    3.10    2.63  2.75  3.10  2.60  2.75  3.15  2.65  2.80  3.10  2.60  2.75  3.10  2.60   3.03   3.30   2.79   2.86   3.18   2.66       2.20       1.67    2.28    1.69      2.38      1.74      2.23      1.67  0.00      2.01      1.92   2.04   1.88     2.06     1.95     2.00     1.87     3230        20
# 2023-02-11    2022           Fulham    Nott'm Forest  E0     2     0   H     1     0   H     A Madley  16  10    3    1   9  11   5   4   0   1   0   0   1.91   3.50   4.33 1.88 3.50 4.10 1.90 3.50 4.20  NaN  NaN  NaN 1.94 3.57 4.37 1.91 3.50 4.00   NaN  NaN  NaN  1.85 3.40 4.20    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.97  3.52  4.33 15:00  1.98  3.70  4.50  1.93  3.56  4.22      2.10      1.73   2.12   1.79     2.18     1.83     2.06     1.78 -0.50     1.93     2.00  1.94  1.98    1.95    2.03    1.91    1.96    1.91    3.50    4.33  1.95  3.40  4.00  1.95  3.45  4.10  1.91  3.40  4.20  1.90  3.30  4.10   2.00   3.61   4.50   1.94   3.51   4.24       2.08       1.82    2.10    1.81      2.13      1.85      2.06      1.80 -0.50      1.95      1.98   1.97   1.95     2.00     2.00     1.94     1.94     3254        22
# 2023-04-01    2022      Bournemouth           Fulham  E0     2     1   H     0     1   A     P Bankes  12  10    7    2  15  13   4   3   1   4   0   0   2.55   3.30   2.80 2.50 3.20 2.85 2.55 3.20 2.90  NaN  NaN  NaN 2.56 3.44 2.89 2.55 3.25 2.75   NaN  NaN  NaN  2.55 3.20 2.80    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.61  3.32  2.97 15:00  2.63  3.52  2.92  2.56  3.34  2.84      2.00      1.80   2.07   1.81     2.11     1.85     2.04     1.80  0.00     1.83     2.07  1.84  2.08    1.86    2.10    1.83    2.03    2.50    3.25    2.90  2.60  3.20  2.80  2.55  3.20  2.90  2.55  3.10  2.88  2.55  3.20  2.90   2.65   3.46   2.99   2.56   3.28   2.90       2.20       1.67    2.24    1.72      2.25      1.83      2.13      1.74  0.00      1.80      2.10   1.84   2.10     1.87     2.14     1.82     2.05     3312        28
# 2023-10-03    2023            Luton          Burnley  E0     1     2   A     0     1   A     P Bankes  18  14    3    4  14   6   7   6   4   2   0   0   2.90   3.00   2.63 2.85 3.10 2.55 2.90 3.10 2.60  NaN  NaN  NaN 2.94 3.23 2.65 2.88 3.10 2.60   NaN  NaN  NaN  2.88 3.13 2.63    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.95  3.22  2.69 19:30  3.00  3.30  2.72  2.92  3.18  2.63      2.20      1.65   2.25   1.70     2.31     1.73     2.24     1.67  0.00     2.08     1.85  2.06  1.85    2.09    1.88    2.03    1.83    2.88    3.10    2.60  2.80  3.10  2.60  2.85  3.15  2.60  2.88  3.10  2.60  2.88  3.13  2.63   3.13   3.30   2.70   2.94   3.16   2.62       2.20       1.65    2.29    1.69      2.35      1.74      2.22      1.66  0.00      2.06      1.87   2.06   1.88     2.14     1.88     2.05     1.82     3490         7
# 2023-12-02    2023          Burnley Sheffield United  E0     5     0   H     2     0   H   C Kavanagh  19   6    7    3   9  12   6   1   2   5   0   1   1.80   3.60   4.50 1.80 3.70 4.33 1.83 3.65 4.30  NaN  NaN  NaN 1.83 3.63 4.65 1.80 3.60 4.20   NaN  NaN  NaN  1.80 3.50 4.50    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.74  3.81  5.19 15:00  1.89  3.82  5.00  1.83  3.68  4.55      2.06      1.84   2.06   1.84     2.10     1.89     2.00     1.84 -0.75     2.03     1.78  2.09  1.81    2.13    1.87    2.06    1.80    1.70    3.60    5.25  1.75  3.60  4.80  1.77  3.60  4.80  1.67  3.70  4.80  1.70  3.70  5.25   1.82   3.88   5.47   1.75   3.73   5.07       2.08       1.73    2.11    1.79      2.16      1.85      2.07      1.78 -0.75      1.97      1.96   1.97   1.95     2.03     2.00     1.96     1.90     3553        14
# 2023-12-26    2023 Sheffield United            Luton  E0     2     3   A     0     1   A    S Allison  21  12    6    4  13  13   9   4   5   0   0   0   2.30   3.30   3.10 2.35 3.25 3.00 2.35 3.30 3.05  NaN  NaN  NaN 2.46 3.32 3.07 2.30 3.25 3.00   NaN  NaN  NaN  2.38 3.13 3.00    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.46  3.29  3.15 15:00  2.52  3.42  3.19  2.41  3.32  3.07      2.10      1.70   2.14   1.76     2.17     1.81     2.11     1.75 -0.25     2.09     1.81  2.12  1.81    2.13    1.88    2.05    1.82    2.38    3.25    3.10  2.45  3.20  3.00  2.50  3.20  2.95  2.38  3.20  2.90  2.45  3.20  3.00   2.57   3.35   3.30   2.46   3.25   3.07       2.15       1.67    2.22    1.72      2.36      1.76      2.19      1.71 -0.25      2.09      1.84   2.11   1.83     2.15     1.85     2.08     1.80     3603        19
# 2024-01-12    2023          Burnley            Luton  E0     1     1   D     1     0   H T Harrington  13  14    7    5   7  12   2   8   1   0   0   0   2.00   3.60   3.60 2.00 3.50 3.60  NaN  NaN  NaN  NaN  NaN  NaN 2.06 3.58 3.80 1.91 3.60 3.60   NaN  NaN  NaN  2.00 3.50 3.80    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.18  3.47  3.60 19:45  2.09  3.75  3.90  2.03  3.58  3.74      1.99      1.91   1.97   1.93     1.99     1.96     1.92     1.88 -0.50     2.06     1.84  2.07  1.87    2.09    1.87    2.03    1.85    2.15    3.40    3.40  2.10  3.40  3.40   NaN   NaN   NaN  2.00  3.50  3.40  2.15  3.40  3.50   2.20   3.55   3.95   2.15   3.46   3.50       2.06       1.84    2.03    1.88      2.06      1.92      1.97      1.87 -0.25      1.87      2.03   1.88   2.06     1.88     2.11     1.83     2.03     3619        20
# 2024-02-10    2023            Luton Sheffield United  E0     1     3   A     0     2   A   C Kavanagh  20   7    5    3   7  12  13   1   1   2   0   0   1.75   3.75   4.75 1.75 3.75 4.50  NaN  NaN  NaN  NaN  NaN  NaN 1.79 3.85 4.60 1.70 3.90 4.40   NaN  NaN  NaN  1.73 3.60 4.60    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  1.72  4.05  4.96 15:00  1.83  4.02  4.75  1.77  3.88  4.59      1.85      2.05   1.88   2.02     1.89     2.13     1.83     2.02 -0.75     2.03     1.90  2.04  1.88    2.04    1.92    1.98    1.88    1.70    3.90    4.75  1.71  3.90  4.60   NaN   NaN   NaN  1.67  3.80  4.75  1.70  3.90  5.00   1.75   4.10   5.10   1.71   3.98   4.87       1.80       2.00    1.81    2.08      1.85      2.12      1.78      2.05 -0.75      1.94      1.99   1.93   1.99     1.95     2.02     1.89     1.96     3651        24
# 2024-04-20    2023 Sheffield United          Burnley  E0     1     4   A     0     2   A     A Madley  18  16   11    9  10   9  11   2   1   0   0   0   2.75   3.60   2.45 2.75 3.60 2.37  NaN  NaN  NaN  NaN  NaN  NaN 2.77 3.64 2.52 2.70 3.60 2.40   NaN  NaN  NaN  2.70 3.50 2.40    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN       NaN       NaN       NaN       NaN   NaN    NaN      NaN      NaN      NaN      NaN  2.66  3.55  2.70 15:00  2.88  3.74  2.55  2.76  3.63  2.47      1.67      2.20   1.69   2.26     1.72     2.31     1.66     2.25  0.00     2.05     1.85  2.05  1.86    2.10    1.87    2.03    1.83    2.60    3.40    2.63  2.55  3.50  2.60   NaN   NaN   NaN  2.62  3.50  2.62  2.60  3.50  2.63   2.76   3.70   2.70   2.64   3.52   2.65       1.73       2.10    1.80    2.10      1.81      2.23      1.75      2.12  0.00      1.93      2.00   1.95   1.98     1.96     2.00     1.93     1.93     3745        33

# %%
#after confirming we remove the matches between two promoted teams
df = df.loc[~mask_promoted_pair].reset_index(drop=True)

# 2.  Quick confirmation
print("Promoted-vs-promoted fixtures removed:", mask_promoted_pair.sum())
print("Remaining rows:", len(df))
# Out:
# Promoted-vs-promoted fixtures removed: 60
# Remaining rows: 3674

# %%
#to check if in the betting odds column all values are present and are numeric as in the research paper 4 values were missing

# --- 1. define the odds columns we require -----------------------------------
odds_cols = ["B365H", "B365D", "B365A"]

# --- 2. make a copy so the original df is untouched for inspection -----------
df_raw = df.copy()

# --- 3. coerce odds to numeric (non‑numeric → NaN) ---------------------------
df_raw[odds_cols] = df_raw[odds_cols].apply(pd.to_numeric, errors="coerce")

# --- 4. identify rows with any missing odds ----------------------------------
missing_mask = df_raw[odds_cols].isna().any(axis=1)
n_missing    = missing_mask.sum()

if n_missing == 0:
    print("✅  All matches have complete Bet365 odds.")
else:
    print(f"⚠️  {n_missing} matches missing at least one Bet365 odd:")
    # show a concise list of the first few problematic rows
    cols_to_show = ["Date", "HomeTeam", "AwayTeam"] + odds_cols
    print(df_raw.loc[missing_mask, cols_to_show].head().to_string(index=False))

# --- 5. drop those rows ------------------------------------------------------
df_clean = df_raw.loc[~missing_mask].reset_index(drop=True)
df=df_clean
print(f"\nRemaining matches after drop: {len(df)}")
# Out:
# ✅  All matches have complete Bet365 odds.
#
# Remaining matches after drop: 3674

# %%
#margin in the betting odds
df["Overround"] = (1/df["B365H"] + 1/df["B365D"] + 1/df["B365A"])
df["InvH"] = 1/df["B365H"]
df["InvA"] = 1/df["B365A"]
df["InvD"] = 1/df["B365D"]
df.tail()
# Out:
#      Div       Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 3669  E0 2024-05-19         Liverpool       Wolves     2     0   H     2
# 3670  E0 2024-05-19             Luton       Fulham     2     4   A     1
# 3671  E0 2024-05-19    Crystal Palace  Aston Villa     5     0   H     2
# 3672  E0 2024-05-19           Chelsea  Bournemouth     2     1   H     1
# 3673  E0 2024-05-19  Sheffield United    Tottenham     0     3   A     0
#
#       HTAG HTR  ... MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  MatchID  Matchday  \
# 3669     0   H  ...    2.10     1.89     2.04     1.82     3797        38
# 3670     2   A  ...    2.02     1.94     1.96     1.91     3798        38
# 3671     0   H  ...    1.93     2.21     1.81     2.05     3796        38
# 3672     0   H  ...    2.02     1.96     1.98     1.89     3795        38
# 3673     1   A  ...    2.08     1.89     2.01     1.86     3800        38
#
#       Overround      InvH      InvA      InvD
# 3669   1.046368  0.854701  0.066667  0.125000
# 3670   1.055783  0.344828  0.454545  0.256410
# 3671   1.049265  0.540541  0.277778  0.230947
# 3672   1.056322  0.689655  0.166667  0.200000
# 3673   1.061404  0.142857  0.751880  0.166667
#
# [5 rows x 137 columns]

# %%
home = pd.DataFrame({
    "MatchID":  df["MatchID"],
    "Season":   df["Season"],
    "Matchday": df["Matchday"],
    "Team":     df["HomeTeam"],
    "Opponent": df["AwayTeam"],
    "IsHome":   1,
    "Odds":     df["B365H"],
    "Outcome":  (df["FTR"]=="H").astype(int),
    "BookProb": df["InvH"] / df["Overround"],
})

away = pd.DataFrame({
    "MatchID":  df["MatchID"],
    "Season":   df["Season"],
    "Matchday": df["Matchday"],
    "Team":     df["AwayTeam"],
    "Opponent": df["HomeTeam"],
    "IsHome":   0,
    "Odds":     df["B365A"],
    "Outcome":  (df["FTR"]=="A").astype(int),
    "BookProb": df["InvA"] / df["Overround"],
})

bets = pd.concat([home, away], ignore_index=True)
bets[bets['MatchID']==38]
# Out:
#       MatchID  Season  Matchday       Team   Opponent  IsHome  Odds  Outcome  \
# 36         38    2014         4  West Brom    Everton       1   3.5        0
# 3710       38    2014         4    Everton  West Brom       0   2.2        1
#
#       BookProb
# 36    0.278481
# 3710  0.443038

# %%
# names of promoted teams
promoted_by_season = {
    2014: {"Burnley", "Leicester", "QPR"},          # 2014/15
    2015: {"Bournemouth", "Norwich", "Watford"},    # 2015/16
    2016: {"Burnley", "Hull", "Middlesbrough"},     # 2016/17
    2017: {"Brighton", "Huddersfield", "Newcastle"},# 2017/18
    2018: {"Cardiff", "Fulham", "Wolves"},          # 2018/19
    2019: {"Aston Villa", "Norwich", "Sheffield United"},   # 2019/20
    2020: {"Fulham", "Leeds", "West Brom"},         # 2020/21
    2021: {"Brentford", "Norwich", "Watford"},      # 2021/22
    2022: {"Bournemouth", "Fulham", "Nott'm Forest"},      # 2022/23
    2023: {"Burnley", "Luton", "Sheffield United"},         # 2023/24
}

#if match has a promoted team
bets["Promoted"] = bets.apply(
    lambda row: row["Team"] in promoted_by_season.get(row["Season"], set()),
    axis=1
).astype(int)

# 6‑C.  Interaction: promoted *and* playing at home
bets["Home_x_Prom"] = bets["IsHome"] * bets["Promoted"]

# 6‑D.  Interaction: promoted team and which match‑day it is
bets["Prom_x_MD"] = bets["Promoted"] * bets["Matchday"]
bets
# Out:
#       MatchID  Season  Matchday         Team          Opponent  IsHome   Odds  \
# 0           1    2014         1      Arsenal    Crystal Palace       1   1.25
# 1           2    2014         1    Leicester           Everton       1   3.20
# 2           3    2014         1   Man United           Swansea       1   1.36
# 3           4    2014         1          QPR              Hull       1   2.50
# 4           5    2014         1        Stoke       Aston Villa       1   1.95
# ...       ...     ...       ...          ...               ...     ...    ...
# 7343     3797    2023        38       Wolves         Liverpool       0  15.00
# 7344     3798    2023        38       Fulham             Luton       0   2.20
# 7345     3796    2023        38  Aston Villa    Crystal Palace       0   3.60
# 7346     3795    2023        38  Bournemouth           Chelsea       0   6.00
# 7347     3800    2023        38    Tottenham  Sheffield United       0   1.33
#
#       Outcome  BookProb  Promoted  Home_x_Prom  Prom_x_MD
# 0           1  0.783920         0            0          0
# 1           0  0.305389         1            1          1
# 2           0  0.716519         0            0          0
# 3           0  0.390011         1            1          1
# 4           0  0.502392         0            0          0
# ...       ...       ...       ...          ...        ...
# 7343        0  0.063712         0            0          0
# 7344        1  0.430529         0            0          0
# 7345        0  0.264736         0            0          0
# 7346        0  0.157780         0            0          0
# 7347        1  0.708383         0            0          0
#
# [7348 rows x 12 columns]

# %%
# bets is the DataFrame in “long” format (one row = one bet)

bets["Profit"] = bets.apply(
    lambda row: (row["Odds"] - 1) if row["Outcome"] == 1 else -1,
    axis=1
)
bets
# Out:
#       MatchID  Season  Matchday         Team          Opponent  IsHome   Odds  \
# 0           1    2014         1      Arsenal    Crystal Palace       1   1.25
# 1           2    2014         1    Leicester           Everton       1   3.20
# 2           3    2014         1   Man United           Swansea       1   1.36
# 3           4    2014         1          QPR              Hull       1   2.50
# 4           5    2014         1        Stoke       Aston Villa       1   1.95
# ...       ...     ...       ...          ...               ...     ...    ...
# 7343     3797    2023        38       Wolves         Liverpool       0  15.00
# 7344     3798    2023        38       Fulham             Luton       0   2.20
# 7345     3796    2023        38  Aston Villa    Crystal Palace       0   3.60
# 7346     3795    2023        38  Bournemouth           Chelsea       0   6.00
# 7347     3800    2023        38    Tottenham  Sheffield United       0   1.33
#
#       Outcome  BookProb  Promoted  Home_x_Prom  Prom_x_MD  Profit
# 0           1  0.783920         0            0          0    0.25
# 1           0  0.305389         1            1          1   -1.00
# 2           0  0.716519         0            0          0   -1.00
# 3           0  0.390011         1            1          1   -1.00
# 4           0  0.502392         0            0          0   -1.00
# ...       ...       ...       ...          ...        ...     ...
# 7343        0  0.063712         0            0          0   -1.00
# 7344        1  0.430529         0            0          0    1.20
# 7345        0  0.264736         0            0          0   -1.00
# 7346        0  0.157780         0            0          0   -1.00
# 7347        1  0.708383         0            0          0    0.33
#
# [7348 rows x 13 columns]

# %%
#84 matches when the promoted team won in away match
# profitable_promoted_bets = bets[(bets['Promoted'] == 1) & (bets['Profit'] > 0) & (bets.index> 1520)]
profitable_promoted_bets = bets[(bets['Promoted'] == 1) & (bets['Outcome'] == 1) & (bets['IsHome'] == 0) & (bets['Profit'] > 0)]
profitable_promoted_bets.sort_values('Profit', ascending=False)
# Out:
#       MatchID  Season  Matchday              Team        Opponent  IsHome  \
# 6147     2572    2020        31         West Brom         Chelsea       0
# 5542     1897    2018        38           Cardiff      Man United       0
# 6512     2951    2021        30         Brentford         Chelsea       0
# 6156     2584    2020        31             Leeds        Man City       0
# 4188      522    2015        15       Bournemouth         Chelsea       0
# ...       ...     ...       ...               ...             ...     ...
# 5783     2142    2019        25  Sheffield United  Crystal Palace       0
# 6946     3393    2022        36            Fulham     Southampton       0
# 4359      694    2015        32       Bournemouth     Aston Villa       0
# 6202     2635    2020        36             Leeds         Burnley       0
# 6061     2467    2020        22             Leeds       Newcastle       0
#
#        Odds  Outcome  BookProb  Promoted  Home_x_Prom  Prom_x_MD  Profit
# 6147  15.00        1  0.063311         1            0         31   14.00
# 5542  11.00        1  0.088605         1            0         38   10.00
# 6512  10.00        1  0.095068         1            0         30    9.00
# 6156  10.00        1  0.094772         1            0         31    9.00
# 4188   9.50        1  0.102095         1            0         15    8.50
# ...     ...      ...       ...       ...          ...        ...     ...
# 5783   2.50        1  0.382716         1            0         25    1.50
# 6946   2.50        1  0.375000         1            0         36    1.50
# 4359   2.20        1  0.428346         1            0         32    1.20
# 6202   2.10        1  0.451213         1            0         36    1.10
# 6061   1.85        1  0.509892         1            0         22    0.85
#
# [84 rows x 13 columns]

# %%
#here we calculate ROI for each matchday so for each matchday the avg was taken and cumulated till the end for each match
# 1️⃣  keep only promoted-away bets
promoted_away = bets[(bets["Promoted"] == 1) & (bets["IsHome"] == 0)]

# 2️⃣  total profit and number of bets on each match-day
day_totals = (promoted_away
              .groupby("Matchday")["Profit"]
              .agg(total_profit="sum", bets="count")
              .sort_index())

# 3️⃣  running cumulative totals up to day k
day_totals["cum_profit"] = day_totals["total_profit"].cumsum()
day_totals["cum_bets"]   = day_totals["bets"].cumsum()

# 4️⃣  cumulative ROI after day k
day_totals["ROI"] = day_totals["cum_profit"] / day_totals["cum_bets"]

# 5️⃣  result: exactly 34 rows, one per match-day
result = day_totals.reset_index()[["Matchday", "ROI"]]
result
# Out:
#     Matchday       ROI
# 0          1 -0.375000
# 1          2 -0.342000
# 2          3 -0.404545
# 3          4 -0.391429
# 4          5 -0.399655
# 5          6 -0.398356
# 6          7 -0.365862
# 7          8 -0.383571
# 8          9 -0.364643
# 9         10 -0.396462
# 10        11 -0.411151
# 11        12 -0.422785
# 12        13 -0.413018
# 13        14 -0.387432
# 14        15 -0.379592
# 15        16 -0.369903
# 16        17 -0.340773
# 17        18 -0.308170
# 18        19 -0.309065
# 19        20 -0.295916
# 20        21 -0.280147
# 21        22 -0.296678
# 22        23 -0.277167
# 23        24 -0.276282
# 24        25 -0.271970
# 25        26 -0.282853
# 26        27 -0.302941
# 27        28 -0.309733
# 28        29 -0.294524
# 29        30 -0.258734
# 30        31 -0.212878
# 31        32 -0.213884
# 32        33 -0.216750
# 33        34 -0.205465
# 34        35 -0.224341
# 35        36 -0.220315
# 36        37 -0.228773
# 37        38 -0.216240

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 0. make sure Profit exists (+odds-1 if win, else -1)
if "Profit" not in bets.columns:
    bets["Profit"] = np.where(bets["Outcome"] == 1,
                              bets["Odds"] - 1,
                              -1)

# helper: cumulative ROI after each match-day (all seasons combined)
def cum_roi_by_day(subset):
    by_day = (subset
              .groupby("Matchday")["Profit"]
              .agg(total_profit="sum", bets="count")
              .sort_index())
    cum_profit = by_day["total_profit"].cumsum()
    cum_bets   = by_day["bets"].cumsum()
    return cum_profit / cum_bets            # ROI up to day k

# three betting strategies
prom_all  = bets[bets["Promoted"] == 1]
prom_home = prom_all[prom_all["IsHome"] == 1]
prom_away = prom_all[prom_all["IsHome"] == 0]

roi_all  = cum_roi_by_day(prom_all)
roi_home = cum_roi_by_day(prom_home)
roi_away = cum_roi_by_day(prom_away)

# bar-plot layout
fig, axes = plt.subplots(3, 1, figsize=(7, 9), sharex=True)

axes[0].bar(roi_all.index,  roi_all.values,  color="grey")
axes[0].set_title("Aggregated cumulative ROI (recently promoted teams)")
axes[0].set_ylabel("ROI")

axes[1].bar(roi_home.index, roi_home.values, color="grey")
axes[1].set_title("(a) Cumulative ROI – promoted teams at home")
axes[1].set_ylabel("ROI")

axes[2].bar(roi_away.index, roi_away.values, color="grey")
axes[2].set_title("(b) Cumulative ROI – promoted teams away")
axes[2].set_xlabel("Match-day (1 – 38)")
axes[2].set_ylabel("ROI")

plt.tight_layout()
plt.show()
